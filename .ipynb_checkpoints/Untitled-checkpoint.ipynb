# %%
import dart_fss as dart
import os
import pandas as pd
import numpy as np
import openpyxl

# %%
df_local_samsung=pd.read_excel('C:/Users/TJ/PycharmProjects/PY/dart/dart_cashflow/samsung_pandas.xlsx')

# %%
df_local_samsung
# Out:
#     Unnamed: 0  \
# 0          NaN
# 1          NaN
# 2          0.0
# 3          1.0
# 4          2.0
# 5          3.0
# 6          4.0
# 7          5.0
# 8          6.0
# 9          7.0
# 10         8.0
# 11         9.0
# 12        10.0
# 13        11.0
# 14        12.0
# 15        13.0
# 16        14.0
# 17        15.0
# 18        16.0
# 19        17.0
# 20        18.0
# 21        19.0
# 22        20.0
# 23        21.0
# 24        22.0
# 25        23.0
# 26        24.0
# 27        25.0
# 28        26.0
# 29        27.0
# 30        28.0
# 31        29.0
# 32        30.0
# 33        31.0
# 34        32.0
# 35        33.0
# 36        34.0
# 37        35.0
# 38        36.0
# 39        37.0
# 40        38.0
# 41        39.0
# 42        40.0
#
#    [D520000] Statement of cash flows, indirect method - Consolidated financial statements (Unit: KRW)  \
# 0                                          concept_id
# 1                                                 NaN
# ...

# %%
df_local_samsung['Unnamed: 0']
# Out:
# 0      NaN
# 1      NaN
# 2      0.0
# 3      1.0
# 4      2.0
# 5      3.0
# 6      4.0
# 7      5.0
# 8      6.0
# 9      7.0
# 10     8.0
# 11     9.0
# 12    10.0
# 13    11.0
# 14    12.0
# 15    13.0
# 16    14.0
# 17    15.0
# 18    16.0
# 19    17.0
# 20    18.0
# 21    19.0
# 22    20.0
# 23    21.0
# 24    22.0
# 25    23.0
# 26    24.0
# 27    25.0
# 28    26.0
# 29    27.0
# 30    28.0
# 31    29.0
# 32    30.0
# 33    31.0
# 34    32.0
# 35    33.0
# 36    34.0
# 37    35.0
# 38    36.0
# 39    37.0
# 40    38.0
# 41    39.0
# 42    40.0
# Name: Unnamed: 0, dtype: float64

# %%
df_local_samsung.columns
# Out:
# Index(['Unnamed: 0',
#        '[D520000] Statement of cash flows, indirect method - Consolidated financial statements (Unit: KRW)',
#        'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6',
#        'Unnamed: 7', '20200101-20201231', 'Unnamed: 9', '20190101-20191231',
#        'Unnamed: 11', '20180101-20181231', 'Unnamed: 13'],
#       dtype='object')

# %%
# 데이터 사이언스 스쿨 연습문제 4.1.2
data = {
    "2015": [9904312, 3448737, 2890451, 2466052],
    "2010": [9631482, 3393191, 2632035, 2431774],
    "2005": [9762546, 3512547, 2517680, 2456016],
    "2000": [9853972, 3655437, 2466338, 2473990]}
columns=['주요지표','2015', '2010','2005', '2000']
index=['매출액','영업이익','경상이익','법인세차감전이익']
df=pd.DataFrame(data, index=index, columns=columns)
df
# Out:
#          주요지표     2015     2010     2005     2000
# 매출액       NaN  9904312  9631482  9762546  9853972
# 영업이익      NaN  3448737  3393191  3512547  3655437
# 경상이익      NaN  2890451  2632035  2517680  2466338
# 법인세차감전이익  NaN  2466052  2431774  2456016  2473990

# %%
# def df["주요지표"] # 이거 왜 안돼
df.drop(['주요지표'], axis=1)
# Out:
#              2015     2010     2005     2000
# 매출액       9904312  9631482  9762546  9853972
# 영업이익      3448737  3393191  3512547  3655437
# 경상이익      2890451  2632035  2517680  2466338
# 법인세차감전이익  2466052  2431774  2456016  2473990

# %%
df[1:2]
type(df[1:2])
# Out:
# pandas.core.frame.DataFrame

# %%
df.T["영업이익"]
type(df.T["영업이익"])
# Out:
# pandas.core.series.Series
